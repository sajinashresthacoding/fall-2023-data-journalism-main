# %% [markdown]
# # Looted Benin Art Work Distribution
#
# Scrape <a href="https://digitalbenin.org/">the Benin site</a> to create a dataframe that contains the following scraped information about each institution:
#
# - Museum name
# - Country
# - Number of disputed items
#
# Export as a ```disputed-benin-artwork.csv```

# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup

# %%
## holding the url and grabbing it

url= "https://digitalbenin.org/institutions"
response = requests.get(url)

# %%
## is the link alive and well? 
response.status_code
# Out:
# 200

# %%
## what type is the url?

type(response)
# Out:
# requests.models.Response

# %%
## let's get a string object so that we can work on it with beautifulsoup later
response.text
# Out:
# '<!DOCTYPE html><html class="h-100"><head><title>Digital Benin</title><link rel="icon" type="image/x-icon" href="/data/digital_benin/media_global/favicon.png"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="stylesheet" href="/style_old.css"><script src="/libraries/jquery/jquery-1.12.2.min.js"></script><script src="/libraries/bootstrap/bootstrap.bundle.min.js">  </script><script src="/deploy.js"></script><script src="/modal.js"></script><script src="/global.js"></script><link rel="stylesheet" href="/libraries/bootstrap/bootstrap.min.css"><link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.8.3/font/bootstrap-icons.css"><link rel="stylesheet" href="/style_global.css"><link rel="stylesheet" href="/style.css"></head><body class="d-flex flex-column h-100"><nav class="navbar navbar-expand-lg navbar-dark bg-black fixed-top shadow-sm" style="z-index:999"><div class="container-fluid"><a class="navbar-brand me-0 overflow-visible ps-2" href="/" style="width:135px"><img src="/data/digital_benin/media_global/header/header_logo.svg"></a><button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarText" aria-controls="navbarText" aria-expanded="false" aria-label="Toggle navigation"><span class="navbar-toggler-icon"></span></button><div class="collapse navbar-collapse justify-content-center pt-3 pt-lg-0" id="navbarText"><div class="navbar-nav mb-2 mb-md-0 fs-5 small-md"><div class="m-1 mx-4"><a class="active-underline link-light" href="/eyo-oto">Ẹyo Otọ</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/catalogue">Catalogue</a></div><div class="m-1 mx-4"><a class="active-underline link-light active" href="/institutions">Institutions</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/provenance">Provenance</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/map">Map</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/oral-history">Oral History</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/itan-edo">Itan Edo</a></div><div class="m-1 mx-4 d-block d-lg-none pb-2"><a class="active-underline link-light" href="/about">About</a></div></div></div><div class="px-2 d-none d-lg-block text-end overflow-visible small"><a class="active-underline link-light" href="/about" style="width:100px">About     </a></div></div></nav><div class="modal fade" id="look-up-modal" tabindex="-1" aria-labelledby="Term look-up modal" aria-hidden="true" style="background:rgba(0,0,0,0.5); z-index: 99999;"><div class="modal-dialog modal-dialog-centered modal-dialog-scrollable"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="exampleModalLabel"><span class="modal-loading-spinner ps-2"><div class="spinner-border spinner-border-sm text-primary" role="status"><span class="visually-hidden">Loading...</span></div></span></h5><button class="btn-close" type="button" data-bs-dismiss="modal" aria-label="Close"></button></div><div class="modal-body" style="white-space:pre-line"><span class="modal-loading-spinner ps-2"><div class="spinner-border spinner-border-sm text-primary" role="status"><span class="visually-hidden">Loading...</span></div></span></div><div class="modal-footer justify-content-start" id="lookup-context-footer"></div><div class="modal-footer justify-content-start" id="lookup-modal-footer"></div></div></div></div><div class="content_hldr" style="padding-top:3.5rem"><script src="../institutions.js"></script><div id="arr_rows" arr_rows="[{&quot;DB_row_id&quot;:&quot;5&quot;,&quot;categories&quot;:[{&quot;DB_name&quot;:&quot;Palace Architecture &amp; Ornamentation&quot;,&quot;DB_id&quot;:12,&quot;DB_count&quot;:210},{&quot;DB_name&quot;:&quot;Altar &amp; Shrine Objects&quot;,&quot;DB_id&quot;:1,&quot;DB_count&quot;:208},{&quot;DB_name&quot;:&quot;Personal Adornment&quot;,&quot;DB_id&quot;:13,&quot;DB_count&quot;:120},{&quot;DB_na ...

# %%
type(response.text)
# Out:
# str
