# %% [markdown]
# # Looted Benin Art Work Distribution
#
# Scrape <a href="https://digitalbenin.org/">the Benin site</a> to create a dataframe that contains the following scraped information about each institution:
#
# - Museum name
# - Country
# - Number of disputed items
#
# Export as a ```disputed-benin-artwork.csv```

# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup

# %%
## holding the url and grabbing it

url= "https://digitalbenin.org/institutions"
response = requests.get(url)

# %%
## is the link alive and well? 
response.status_code
# Out:
# 200

# %%
## what type is the url?

type(response)
# Out:
# requests.models.Response

# %%
## let's get a string object so that we can work on it with beautifulsoup later
response.text
# Out:
# '<!DOCTYPE html><html class="h-100"><head><title>Digital Benin</title><link rel="icon" type="image/x-icon" href="/data/digital_benin/media_global/favicon.png"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="stylesheet" href="/style_old.css"><script src="/libraries/jquery/jquery-1.12.2.min.js"></script><script src="/libraries/bootstrap/bootstrap.bundle.min.js">  </script><script src="/deploy.js"></script><script src="/modal.js"></script><script src="/global.js"></script><link rel="stylesheet" href="/libraries/bootstrap/bootstrap.min.css"><link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.8.3/font/bootstrap-icons.css"><link rel="stylesheet" href="/style_global.css"><link rel="stylesheet" href="/style.css"></head><body class="d-flex flex-column h-100"><nav class="navbar navbar-expand-lg navbar-dark bg-black fixed-top shadow-sm" style="z-index:999"><div class="container-fluid"><a class="navbar-brand me-0 overflow-visible ps-2" href="/" style="width:135px"><img src="/data/digital_benin/media_global/header/header_logo.svg"></a><button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarText" aria-controls="navbarText" aria-expanded="false" aria-label="Toggle navigation"><span class="navbar-toggler-icon"></span></button><div class="collapse navbar-collapse justify-content-center pt-3 pt-lg-0" id="navbarText"><div class="navbar-nav mb-2 mb-md-0 fs-5 small-md"><div class="m-1 mx-4"><a class="active-underline link-light" href="/eyo-oto">Ẹyo Otọ</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/catalogue">Catalogue</a></div><div class="m-1 mx-4"><a class="active-underline link-light active" href="/institutions">Institutions</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/provenance">Provenance</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/map">Map</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/oral-history">Oral History</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/itan-edo">Itan Edo</a></div><div class="m-1 mx-4 d-block d-lg-none pb-2"><a class="active-underline link-light" href="/about">About</a></div></div></div><div class="px-2 d-none d-lg-block text-end overflow-visible small"><a class="active-underline link-light" href="/about" style="width:100px">About     </a></div></div></nav><div class="modal fade" id="look-up-modal" tabindex="-1" aria-labelledby="Term look-up modal" aria-hidden="true" style="background:rgba(0,0,0,0.5); z-index: 99999;"><div class="modal-dialog modal-dialog-centered modal-dialog-scrollable"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="exampleModalLabel"><span class="modal-loading-spinner ps-2"><div class="spinner-border spinner-border-sm text-primary" role="status"><span class="visually-hidden">Loading...</span></div></span></h5><button class="btn-close" type="button" data-bs-dismiss="modal" aria-label="Close"></button></div><div class="modal-body" style="white-space:pre-line"><span class="modal-loading-spinner ps-2"><div class="spinner-border spinner-border-sm text-primary" role="status"><span class="visually-hidden">Loading...</span></div></span></div><div class="modal-footer justify-content-start" id="lookup-context-footer"></div><div class="modal-footer justify-content-start" id="lookup-modal-footer"></div></div></div></div><div class="content_hldr" style="padding-top:3.5rem"><script src="../institutions.js"></script><div id="arr_rows" arr_rows="[{&quot;DB_row_id&quot;:&quot;5&quot;,&quot;categories&quot;:[{&quot;DB_name&quot;:&quot;Palace Architecture &amp; Ornamentation&quot;,&quot;DB_id&quot;:12,&quot;DB_count&quot;:210},{&quot;DB_name&quot;:&quot;Altar &amp; Shrine Objects&quot;,&quot;DB_id&quot;:1,&quot;DB_count&quot;:208},{&quot;DB_name&quot;:&quot;Personal Adornment&quot;,&quot;DB_id&quot;:13,&quot;DB_count&quot;:120},{&quot;DB_na ...

# %%
type(response.text)
# Out:
# str

# %%
## bringing in beautifulsoup to recreate our string into html and css

soup = BeautifulSoup(response.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html class="h-100"><head><title>Digital Benin</title><link href="/data/digital_benin/media_global/favicon.png" rel="icon" type="image/x-icon"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="/style_old.css" rel="stylesheet"/><script src="/libraries/jquery/jquery-1.12.2.min.js"></script><script src="/libraries/bootstrap/bootstrap.bundle.min.js"> </script><script src="/deploy.js"></script><script src="/modal.js"></script><script src="/global.js"></script><link href="/libraries/bootstrap/bootstrap.min.css" rel="stylesheet"/><link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.8.3/font/bootstrap-icons.css" rel="stylesheet"/><link href="/style_global.css" rel="stylesheet"/><link href="/style.css" rel="stylesheet"/></head><body class="d-flex flex-column h-100"><nav class="navbar navbar-expand-lg navbar-dark bg-black fixed-top shadow-sm" style="z-index:999"><div class="container-fluid"><a class="navbar-brand me-0 overflow-visible ps-2" href="/" style="width:135px"><img src="/data/digital_benin/media_global/header/header_logo.svg"/></a><button aria-controls="navbarText" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarText" data-bs-toggle="collapse" type="button"><span class="navbar-toggler-icon"></span></button><div class="collapse navbar-collapse justify-content-center pt-3 pt-lg-0" id="navbarText"><div class="navbar-nav mb-2 mb-md-0 fs-5 small-md"><div class="m-1 mx-4"><a class="active-underline link-light" href="/eyo-oto">Ẹyo Otọ</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/catalogue">Catalogue</a></div><div class="m-1 mx-4"><a class="active-underline link-light active" href="/institutions">Institutions</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/provenance">Provenance</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/map">Map</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/oral-history">Oral History</a></div><div class="m-1 mx-4"><a class="active-underline link-light" href="/itan-edo">Itan Edo</a></div><div class="m-1 mx-4 d-block d-lg-none pb-2"><a class="active-underline link-light" href="/about">About</a></div></div></div><div class="px-2 d-none d-lg-block text-end overflow-visible small"><a class="active-underline link-light" href="/about" style="width:100px">About     </a></div></div></nav><div aria-hidden="true" aria-labelledby="Term look-up modal" class="modal fade" id="look-up-modal" style="background:rgba(0,0,0,0.5); z-index: 99999;" tabindex="-1"><div class="modal-dialog modal-dialog-centered modal-dialog-scrollable"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="exampleModalLabel"><span class="modal-loading-spinner ps-2"><div class="spinner-border spinner-border-sm text-primary" role="status"><span class="visually-hidden">Loading...</span></div></span></h5><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body" style="white-space:pre-line"><span class="modal-loading-spinner ps-2"><div class="spinner-border spinner-border-sm text-primary" role="status"><span class="visually-hidden">Loading...</span></div></span></div><div class="modal-footer justify-content-start" id="lookup-context-footer"></div><div class="modal-footer justify-content-start" id="lookup-modal-footer"></div></div></div></div><div class="content_hldr" style="padding-top:3.5rem"><script src="../institutions.js"></script><div arr_rows='[{"DB_row_id":"5","categories":[{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":210},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":208},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":120},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":107},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":97},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":82},{"DB_name": ...
# </span><a class="d-inline-block fw-semibold text-decoration-none" data-bs-target="#modal_introduction" data-bs-toggle="modal" role="button">Read more</a></div></div></div><div id="scrollto_hashchange"><div class="border border-2 border-primary rounded-1 py-1 px-2 mt-3" id="filtered_by_main" style="display:none"><div class="text-muted small">Filtered by:</div><span><b id="filtered_by_name"></b></span><div class="text-primary small clear_filter cursor-pointer">Clear filter</div></div><div class="border border-2 border-primary rounded-1 py-1 px-2 mt-3" id="filtered_by_category" style="display:none"><div class="text-muted small">Filtered by:</div><span><b id="filtered_by_name"></b></span><span>: </span><span id="filtered_by_main_desc"></span><div class="text-primary small clear_filter cursor-pointer">Clear filter</div></div></div></div><div class="container-xxl"><div class="border-top border-dark"><div class="sticky-top border-bottom bg-white" style="top:3.5rem;z-index:99"><div class="border-top border-dark" style="position:relative; top: -1px"><div class="row g-2 g-md-0 gx-md-3 py-3"><div class="col-6 col-md-5 sortby_alpha" sortby="museum" sortflip="false"><div class="d-grid d-md-block"><a class="btn btn-outline-dark btn-sm"><span class="fw-semibold pe-1">Institutions</span><span class="sortaz_icon"><i class="bi bi-sort-alpha-down"> </i></span><span class="sortza_icon" style="display:none"><i class="bi bi-sort-alpha-up"> </i></span></a><span class="d-none d-lg-inline small text-muted count_rows"></span></div></div><div class="col-6 col-md-auto inst-col-filter"><div class="d-grid d-md-block"><a class="btn btn-outline-dark btn-sm" data-bs-target="#modal_main" data-bs-toggle="modal" role="button"><span class="fw-semibold pe-1">Filter by Country</span><span><i class="bi bi-funnel"></i></span></a></div></div><div class="col-6 col-md-auto sortby_num inst-col-count" sortby="count" sortflip="true"><div class="d-grid d-md-block"><a class="btn btn-outline-dark btn-sm"><span class="fw-semibold pe-1"># Objects</span><span class="sortaz_icon"><i class="bi bi-sort-numeric-down"></i></span><span class="sortza_icon" style="display:none"><i class="bi bi-sort-numeric-up"></i></span></a></div></div><div class="col-6 col-md sortby_num"><div class="d-grid d-md-block"><a class="btn btn-outline-dark btn-sm" data-bs-dismiss="modal" data-bs-target="#modal_categories" data-bs-toggle="modal" role="button"><span class="fw-semibold pe-1">Filter by Category</span><span><i class="bi bi-funnel"></i></span></a><span class="d-none d-lg-inline small text-muted count_obj"></span></div></div></div></div><div class="d-lg-none text-dark small py-2 border-top"><span>Showing </span><span class="count_rows_mobile"></span><span class="ms-1 count_obj_mobile"></span></div></div><div class="bg-white" id="sortable_elems"><div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_12 cat_1 cat_13 cat_5 cat_11 cat_4 cat_8 cat_6 cat_14 cat_19 cat_18 cat_7 cat_16 cat_3 cat_20 cat_2 cat_10 cat_24 cat_15 cat_0 main_unitedkingdom" row_id="5" test='[{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":210},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":208},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":120},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":107},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":97},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":82},{"DB_name":"Figures","DB_id":8,"DB_count":74},{"DB_name":"Containers","DB_id":6,"DB_count":70},{"DB_name":"Staffs","DB_id":14,"DB_count":55},{"DB_name":"Heads","DB_id":19,"DB_count":51},{"DB_name":"Weaponry","DB_id":18,"DB_count":26},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":21},{"DB_name":"Tools","DB_id":16,"DB_count":14},{"DB_name":"Casting Materials","DB_id":3,"DB_count":10},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":8},{"DB_name":"Contextual Objects: Benin-Portugues ...
# " filter_id="15" filter_name="Textiles" filter_readmore="0"><div class="row"><div class="col"><div>Textiles</div></div><div class="col-auto"><div>9</div></div></div></span><span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="Objects used in healing and divining, often described as 'medicine'. These objects may be used by practitioners or priests, placed on altars and shrines, or worn by individuals for protection and good health. Osun, the Edo deity of medicine, is most commonly associated with objects of this kind.
#
#
# " filter_id="10" filter_name="Healing &amp; Divining Objects" filter_readmore="0"><div class="row"><div class="col"><div>Healing &amp; Divining Objects</div></div><div class="col-auto"><div>9</div></div></div></span><span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="After Ọba Ovanramwen was removed from power and exiled by the British in 1897, the palace structures which organised the production of artworks in Benin City via the guild system were disrupted. In 1914 the interregnum ended and Ọba Eweka II was instated as Ọba of Benin; by 1927 the Benin... " filter_id="24" filter_name="Contextual Objects: Post-1930s" filter_readmore="1"><div class="row"><div class="col"><div>Contextual Objects: Post-1930s</div></div><div class="col-auto"><div>4</div></div></div></span></div></div><div class="modal-footer"><button class="btn btn-dark filter_category" data-bs-dismiss="modal" filter_id="all" type="button">Show all</button><button class="btn btn-secondary" data-bs-dismiss="modal" type="button">Close</button></div></div></div></div><div aria-hidden="true" aria-labelledby="modal_introductionLabel" class="modal fade" id="modal_introduction" tabindex="-1"><div class="modal-dialog modal-lg modal-dialog-scrollable modal-dialog-centered"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="modal_introductionLabel">Institutions</h5><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><p style="white-space:pre-line;">Study each institutional collection of Benin objects and sort the list of institutions by name, object count and country. Selecting an institution gives access to an introduction page with details about the institution, the collected data and an overview of object groups in the collection.
# </p><p style="white-space:pre-line;">The approach of preserving the structure and content of the digital material shared by the museums shows how each institution provides context for the objects. The Digital Benin-authored content in this space is labeled as such.
# </p></div><div class="modal-footer"><a class="btn btn-dark" href="/documentation/data-acquisition-and-data-management">See documentation</a><button class="btn btn-secondary" data-bs-dismiss="modal" type="button">Close</button></div></div></div></div></div><footer class="footer mt-auto pt-5"><div class="container-fluid py-3 bg-black text-light small"><div class="row py-4"><div class="col-12 col-md-3 text-center text-md-start"><a href="/"><img class="p-4 pt-0 w-100 pb-5" src="/data/digital_benin/media_global/footer/footer_logo.svg" style="max-width:200px"/></a></div><div class="col col-md-2"><div class="pb-3 fw-bolder">INFO</div><div><a class="link-secondary text-decoration-none link-secondary" href="/eyo-oto"> Eyo Otọ </a></div><div><a class="link-secondary text-decoration-none" href="/catalogue"> Catalogue </a></div><div><a class="link-secondary text-decoration-none" href="/institutions"> Institutions </a></div><div><a class="link-secondary text-decoration-none" href="/provenance"> Provenance </a></div><div><a class="link-secondary text-decoration-none" href="/map"> Map</a></div><div><a class="link-secondary text-decoration-none" href="/oral-history"> Oral history </a></div><div><a class="link-secondary text-decoration-none" href="/itan-edo"> Itan Edo</a></div><div><a class="link-secondary text-decoration-none" href="/media"> Media</a></div></div><div class="col col-md-2"><div class="pb-3 fw-bolder">ABOUT</div><div><a class="link-secondary text-decoration-none" href="/team">Team </a></div><div><a class="link-secondary text-decoration-none" href="/funding-and-host"> Funding &amp; host </a></div><div><a class="link-secondary text-decoration-none" href="/documentation"> Documentation</a></div><div><a class="link-secondary text-decoration-none" href="/bibliography"> Bibliography</a></div><div><a class="link-secondary text-decoration-none" href="/media"> Media</a></div></div><div class="col col-md-2"><div class="pb-3 fw-bolder">OTHER</div><div><a class="link-secondary text-decoration-none" href="/data-privacy-policy">Data privacy policy </a></div><div><a class="link-secondary text-decoration-none" href="/imprint"> Imprint</a></div></div><div class="col-12 col-md-3"><div class="pt-4 pt-md-1 text-center scrolltotop cursor-pointer"><img class="pb-4" src="/data/digital_benin/media_global/footer/back_to_top.svg" style="max-width:60px"/><div class="fw-bolder">BACK TO TOP </div></div></div></div></div></footer></body></html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="h-100">
#  <head>
#   <title>
#    Digital Benin
#   </title>
#   <link href="/data/digital_benin/media_global/favicon.png" rel="icon" type="image/x-icon"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/style_old.css" rel="stylesheet"/>
#   <script src="/libraries/jquery/jquery-1.12.2.min.js">
#   </script>
#   <script src="/libraries/bootstrap/bootstrap.bundle.min.js">
#   </script>
#   <script src="/deploy.js">
#   </script>
#   <script src="/modal.js">
#   </script>
#   <script src="/global.js">
#   </script>
#   <link href="/libraries/bootstrap/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.8.3/font/bootstrap-icons.css" rel="stylesheet"/>
#   <link href="/style_global.css" rel="stylesheet"/>
#   <link href="/style.css" rel="stylesheet"/>
#  </head>
#  <body class="d-flex flex-column h-100">
#   <nav class="navbar navbar-expand-lg navbar-dark bg-black fixed-top shadow-sm" style="z-index:999">
#    <div class="container-fluid">
#     <a class="navbar-brand me-0 overflow-visible ps-2" href="/" style="width:135px">
#      <img src="/data/digital_benin/media_global/header/header_logo.svg"/>
#     </a>
#     <button aria-controls="navbarText" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarText" data-bs-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon">
#      </span>
#     </button>
#     <div class="collapse navbar-collapse justify-content-center pt-3 pt-lg-0" id="navbarText">
#      <div class="navbar-nav mb-2 mb-md-0 fs-5 small-md">
#       <div class="m-1 mx-4">
#        <a class="active-underline link-light" href="/eyo-oto">
#         Ẹyo Otọ
#        </a>
#       </div>
#       <div class="m-1 mx-4">
#        <a class="active-underline link-light" href="/catalogue">
#         Catalogue
#        </a>
#       </div>
#       <div class="m-1 mx-4">
#        <a class="active-underline link-light active" href="/institutions">
#         Institutions
#        </a>
#       </div>
#       <div class="m-1 mx-4">
#        <a class="active-underline link-light" href="/provenance">
#         Provenance
#        </a>
#       </div>
#       <div class="m-1 mx-4">
#        <a class="active-underline link-light" href="/map">
#         Map
#        </a>
#       </div>
#       <div class="m-1 mx-4">
#        <a class="active-underline link-light" href="/oral-history">
#         Oral History
#        </a>
#       </div>
#       <div class="m-1 mx-4">
#        <a class="active-underline link-light" href="/itan-edo">
#         Itan Edo
#        </a>
#       </div>
#       <div class="m-1 mx-4 d-block d-lg-none pb-2">
#        <a class="active-underline link-light" href="/about">
#         About
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="px-2 d-none d-lg-block text-end overflow-visible small">
#      <a class="active-underline link-light" href="/about" style="width:100px">
#       About
#      </a>
#     </div>
#    </div>
#   </nav>
#   <div aria-hidden="true" aria-labelledby="Term look-up modal" class="modal fade" id="look-up-modal" style="background:rgba(0,0,0,0.5); z-index: 99999;" tabindex="-1">
#    <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable">
#     <div class="modal-content">
#      <div class="modal-header">
#       <h5 class="modal-title" id="exampleModalLabel">
#        <span class="modal-loading-spinner ps-2">
#         <div class="spinner-border spinner-border-sm text-primary" role="status">
#          <span class="visually-hidden">
#           Loading...
#          </span>
#         </div>
#        </span>
#       </h5>
#       <button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button">
#       </button>
#      </div>
#      <div class="modal-body" style="white-space:pre-line">
#       <span class="modal-loading-spinner ps-2">
#        <div class="spinner-border spinner-border-sm text-primary" role="status">
#         <span class="visually-hidden">
#          Loading...
#         </span>
#        </div>
#       </span>
#      </div>
#      <div class="modal-footer justify-content-start" id="lookup-context-footer">
#      </div>
#      <div class="modal-footer justify-content-start" id="lookup-modal-footer">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="content_hldr" style="padding-top:3.5rem">
#    <script src="../institutions.js">
#    </script>
#    <div arr_rows='[{"DB_row_id":"5","categories":[{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":210},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":208},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":120},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":107},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":97},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":82},{"DB_name":"Figures","DB_id":8,"DB_count":74},{"DB_name":"Containers","DB_id":6,"DB_count":70},{"DB_name":"Staffs","DB_id":14,"DB_count":55},{"DB_name":"Heads","DB_id":19,"DB_count":51},{"DB_name":"Weaponry","DB_id":18,"DB_count":26},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":21},{"DB_name":"Tools","DB_id":16,"DB_count":14},{"DB_name":"Casting Materials","DB_id":3,"DB_count":10},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":8},{"DB_name":"Contextual Objects: Benin-Portuguese Ivories","DB_id":2,"DB_count":8},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":5},{"DB_name":"Contextual Objects: Post-1930s","DB_id":24,"DB_count":1},{"DB_name":"Textiles","DB_id":15,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":16}]},{"DB_row_id":"13","categories":[{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":384},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":204},{"DB_name":"Figures","DB_id":8,"DB_count":84},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":81},{"DB_name":"Heads","DB_id":19,"DB_count":81},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":81},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":72},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":57},{"DB_name":"Containers","DB_id":6,"DB_count":51},{"DB_name":"Staffs","DB_id":14,"DB_count":50},{"DB_name":"Weaponry","DB_id":18,"DB_count":10},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":5},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":4},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":4},{"DB_name":"Contextual Objects: Benin-Portuguese Ivories","DB_id":2,"DB_count":2},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":2},{"DB_name":"Tools","DB_id":16,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":7}]},{"DB_row_id":"15","categories":[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":96},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":85},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":65},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":49},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":48},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":48},{"DB_name":"Containers","DB_id":6,"DB_count":32},{"DB_name":"Staffs","DB_id":14,"DB_count":26},{"DB_name":"Weaponry","DB_id":18,"DB_count":21},{"DB_name":"Figures","DB_id":8,"DB_count":20},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":15},{"DB_name":"Heads","DB_id":19,"DB_count":13},{"DB_name":"Tools","DB_id":16,"DB_count":6},{"DB_name":"Casting Materials","DB_id":3,"DB_count":4},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":2},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":1},{"DB_name":"Textiles","DB_id":15,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":5}]},{"DB_row_id":"28","categories":[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":73},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":52},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":46},{"DB_name":"Staffs","DB_id":14,"DB_count":43},{"DB_name":"Containers","DB_id":6,"DB_count":42},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":34},{"DB_name":"Figures","DB_id":8,"DB_count":28},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":23},{"DB_name":"Tools","DB_id":16,"DB_count":21},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":15},{"DB_name":"Ceremonial Objects"," ...
#    </div>
#    <div id="num_total_objects" num_total_objects="5246">
#    </div>
#    <div class="container py-4" style="max-width:1100px">
#     <div class="row g-0">
#      <div class="col-12 col-sm-4 col-md-3 text-center">
#       <img class="d-inline-block w-100 px-2" src="/data/digital_benin/media_global/doors/png/institutions.png" style="max-width:200px;margin-top:-20px"/>
#      </div>
#      <div class="col">
#       <h1 class="pb-2 fw-bolder">
#        Institutions
#       </h1>
#       <div>
#        <span class="me-1">
#         Study each institutional collection of Benin objects and sort the list of institutions by name, object count and country. Selecting an institution gives access to an introduction page with details about the institution, the collected data and an overview of object groups in the collection.
#        </span>
#        <a class="d-inline-block fw-semibold text-decoration-none" data-bs-target="#modal_introduction" data-bs-toggle="modal" role="button">
#         Read more
#        </a>
#       </div>
#      </div>
#     </div>
#     <div id="scrollto_hashchange">
#      <div class="border border-2 border-primary rounded-1 py-1 px-2 mt-3" id="filtered_by_main" style="display:none">
#       <div class="text-muted small">
#        Filtered by:
#       </div>
#       <span>
#        <b id="filtered_by_name">
#        </b>
#       </span>
#       <div class="text-primary small clear_filter cursor-pointer">
#        Clear filter
#       </div>
#      </div>
#      <div class="border border-2 border-primary rounded-1 py-1 px-2 mt-3" id="filtered_by_category" style="display:none">
#       <div class="text-muted small">
#        Filtered by:
#       </div>
#       <span>
#        <b id="filtered_by_name">
#        </b>
#       </span>
#       <span>
#        :
#       </span>
#       <span id="filtered_by_main_desc">
#       </span>
#       <div class="text-primary small clear_filter cursor-pointer">
#        Clear filter
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container-xxl">
#     <div class="border-top border-dark">
#      <div class="sticky-top border-bottom bg-white" style="top:3.5rem;z-index:99">
#       <div class="border-top border-dark" style="position:relative; top: -1px">
#        <div class="row g-2 g-md-0 gx-md-3 py-3">
#         <div class="col-6 col-md-5 sortby_alpha" sortby="museum" sortflip="false">
#          <div class="d-grid d-md-block">
#           <a class="btn btn-outline-dark btn-sm">
#            <span class="fw-semibold pe-1">
#             Institutions
#            </span>
#            <span class="sortaz_icon">
#             <i class="bi bi-sort-alpha-down">
#             </i>
#            </span>
#            <span class="sortza_icon" style="display:none">
#             <i class="bi bi-sort-alpha-up">
#             </i>
#            </span>
#           </a>
#           <span class="d-none d-lg-inline small text-muted count_rows">
#           </span>
#          </div>
#         </div>
#         <div class="col-6 col-md-auto inst-col-filter">
#          <div class="d-grid d-md-block">
#           <a class="btn btn-outline-dark btn-sm" data-bs-target="#modal_main" data-bs-toggle="modal" role="button">
#            <span class="fw-semibold pe-1">
#             Filter by Country
#            </span>
#            <span>
#             <i class="bi bi-funnel">
#             </i>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="col-6 col-md-auto sortby_num inst-col-count" sortby="count" sortflip="true">
#          <div class="d-grid d-md-block">
#           <a class="btn btn-outline-dark btn-sm">
#            <span class="fw-semibold pe-1">
#             # Objects
#            </span>
#            <span class="sortaz_icon">
#             <i class="bi bi-sort-numeric-down">
#             </i>
#            </span>
#            <span class="sortza_icon" style="display:none">
#             <i class="bi bi-sort-numeric-up">
#             </i>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="col-6 col-md sortby_num">
#          <div class="d-grid d-md-block">
#           <a class="btn btn-outline-dark btn-sm" data-bs-dismiss="modal" data-bs-target="#modal_categories" data-bs-toggle="modal" role="button">
#            <span class="fw-semibold pe-1">
#             Filter by Category
#            </span>
#            <span>
#             <i class="bi bi-funnel">
#             </i>
#            </span>
#           </a>
#           <span class="d-none d-lg-inline small text-muted count_obj">
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="d-lg-none text-dark small py-2 border-top">
#        <span>
#         Showing
#        </span>
#        <span class="count_rows_mobile">
#        </span>
#        <span class="ms-1 count_obj_mobile">
#        </span>
#       </div>
#      </div>
#      <div class="bg-white" id="sortable_elems">
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_12 cat_1 cat_13 cat_5 cat_11 cat_4 cat_8 cat_6 cat_14 cat_19 cat_18 cat_7 cat_16 cat_3 cat_20 cat_2 cat_10 cat_24 cat_15 cat_0 main_unitedkingdom" row_id="5" test='[{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":210},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":208},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":120},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":107},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":97},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":82},{"DB_name":"Figures","DB_id":8,"DB_count":74},{"DB_name":"Containers","DB_id":6,"DB_count":70},{"DB_name":"Staffs","DB_id":14,"DB_count":55},{"DB_name":"Heads","DB_id":19,"DB_count":51},{"DB_name":"Weaponry","DB_id":18,"DB_count":26},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":21},{"DB_name":"Tools","DB_id":16,"DB_count":14},{"DB_name":"Casting Materials","DB_id":3,"DB_count":10},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":8},{"DB_name":"Contextual Objects: Benin-Portuguese Ivories","DB_id":2,"DB_count":8},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":5},{"DB_name":"Contextual Objects: Post-1930s","DB_id":24,"DB_count":1},{"DB_name":"Textiles","DB_id":15,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":16}]'>
#        <div class="col-12 col-md-5" sort="museum" val="British Museum">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/5">
#            British Museum
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">
#            United Kingdom
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="944" inst="British Museum" sort="count" val="944">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="944">
#           944
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/5" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="100" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:100%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_12 cat_1 cat_8 cat_4 cat_19 cat_13 cat_5 cat_11 cat_6 cat_14 cat_18 cat_17 cat_20 cat_7 cat_2 cat_10 cat_16 cat_0 main_germany" row_id="13" test='[{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":384},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":204},{"DB_name":"Figures","DB_id":8,"DB_count":84},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":81},{"DB_name":"Heads","DB_id":19,"DB_count":81},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":81},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":72},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":57},{"DB_name":"Containers","DB_id":6,"DB_count":51},{"DB_name":"Staffs","DB_id":14,"DB_count":50},{"DB_name":"Weaponry","DB_id":18,"DB_count":10},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":5},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":4},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":4},{"DB_name":"Contextual Objects: Benin-Portuguese Ivories","DB_id":2,"DB_count":2},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":2},{"DB_name":"Tools","DB_id":16,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":7}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Ethnologisches Museum, Staatliche Museen zu Berlin">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/13">
#            Ethnologisches Museum, Staatliche Museen zu Berlin
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">
#            Germany
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="518" inst="Ethnologisches Museum, Staatliche Museen zu Berlin" sort="count" val="518">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="518">
#           518
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/13" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="54.8728813559322" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:54.8728813559322%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_5 cat_11 cat_12 cat_4 cat_13 cat_6 cat_14 cat_18 cat_8 cat_7 cat_19 cat_16 cat_3 cat_17 cat_10 cat_15 cat_0 main_unitedstates" row_id="15" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":96},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":85},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":65},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":49},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":48},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":48},{"DB_name":"Containers","DB_id":6,"DB_count":32},{"DB_name":"Staffs","DB_id":14,"DB_count":26},{"DB_name":"Weaponry","DB_id":18,"DB_count":21},{"DB_name":"Figures","DB_id":8,"DB_count":20},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":15},{"DB_name":"Heads","DB_id":19,"DB_count":13},{"DB_name":"Tools","DB_id":16,"DB_count":6},{"DB_name":"Casting Materials","DB_id":3,"DB_count":4},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":2},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":1},{"DB_name":"Textiles","DB_id":15,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":5}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Field Museum">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/15">
#            Field Museum
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">
#            United States
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="393" inst="Field Museum" sort="count" val="393">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="393">
#           393
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/15" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="41.63135593220339" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:41.63135593220339%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_7 cat_13 cat_14 cat_6 cat_5 cat_8 cat_11 cat_16 cat_12 cat_4 cat_17 cat_15 cat_19 cat_20 cat_18 cat_10 cat_0 main_unitedkingdom" row_id="28" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":73},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":52},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":46},{"DB_name":"Staffs","DB_id":14,"DB_count":43},{"DB_name":"Containers","DB_id":6,"DB_count":42},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":34},{"DB_name":"Figures","DB_id":8,"DB_count":28},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":23},{"DB_name":"Tools","DB_id":16,"DB_count":21},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":15},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":14},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":14},{"DB_name":"Textiles","DB_id":15,"DB_count":13},{"DB_name":"Heads","DB_id":19,"DB_count":10},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":9},{"DB_name":"Weaponry","DB_id":18,"DB_count":7},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":5},{"DB_name":"Unassigned","DB_id":0,"DB_count":6}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Museum of Archaeology and Anthropology, University of Cambridge">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/28">
#            Museum of Archaeology and Anthropology, University of Cambridge
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">
#            United Kingdom
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="350" inst="Museum of Archaeology and Anthropology, University of Cambridge" sort="count" val="350">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="350">
#           350
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/28" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="37.07627118644068" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:37.07627118644068%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_13 cat_11 cat_12 cat_5 cat_4 cat_14 cat_8 cat_19 cat_18 cat_16 cat_6 cat_7 cat_17 cat_10 cat_20 cat_0 main_nigeria" row_id="36" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":70},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":42},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":29},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":28},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":25},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":24},{"DB_name":"Staffs","DB_id":14,"DB_count":21},{"DB_name":"Figures","DB_id":8,"DB_count":18},{"DB_name":"Heads","DB_id":19,"DB_count":16},{"DB_name":"Weaponry","DB_id":18,"DB_count":16},{"DB_name":"Tools","DB_id":16,"DB_count":14},{"DB_name":"Containers","DB_id":6,"DB_count":13},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":6},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":6},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":1},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":28}]'>
#        <div class="col-12 col-md-5" sort="museum" val="National Museum, Benin">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/36">
#            National Museum, Benin
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Nigeria">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="nigeria" role="button" style="max-width:100% margin: 2px 0">
#            Nigeria
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="285" inst="National Museum, Benin" sort="count" val="285">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="285">
#           285
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/36" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="30.190677966101692" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:30.190677966101692%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_12 cat_5 cat_4 cat_8 cat_11 cat_13 cat_19 cat_14 cat_6 cat_20 cat_17 cat_7 cat_0 main_germany" row_id="47" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":67},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":63},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":43},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":36},{"DB_name":"Figures","DB_id":8,"DB_count":32},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":30},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":25},{"DB_name":"Heads","DB_id":19,"DB_count":24},{"DB_name":"Staffs","DB_id":14,"DB_count":21},{"DB_name":"Containers","DB_id":6,"DB_count":14},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":9},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":5},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":2},{"DB_name":"Unassigned","DB_id":0,"DB_count":9}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Staatliche Ethnographische Sammlungen Sachsen und Staatliche Kunstsammlungen Dresden">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/47">
#            Staatliche Ethnographische Sammlungen Sachsen und Staatliche Kunstsammlungen Dresden
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">
#            Germany
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="283" inst="Staatliche Ethnographische Sammlungen Sachsen und Staatliche Kunstsammlungen Dresden" sort="count" val="283">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="283">
#           283
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/47" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="29.97881355932203" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:29.97881355932203%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_12 cat_8 cat_5 cat_13 cat_11 cat_4 cat_14 cat_19 cat_6 cat_2 cat_18 cat_10 cat_7 cat_16 cat_20 cat_15 cat_17 main_austria" row_id="50" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":57},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":47},{"DB_name":"Figures","DB_id":8,"DB_count":22},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":20},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":20},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":20},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":15},{"DB_name":"Staffs","DB_id":14,"DB_count":15},{"DB_name":"Heads","DB_id":19,"DB_count":10},{"DB_name":"Containers","DB_id":6,"DB_count":10},{"DB_name":"Contextual Objects: Benin-Portuguese Ivories","DB_id":2,"DB_count":6},{"DB_name":"Weaponry","DB_id":18,"DB_count":3},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":2},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":2},{"DB_name":"Tools","DB_id":16,"DB_count":2},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":2},{"DB_name":"Textiles","DB_id":15,"DB_count":1},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":1}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Weltmuseum Wien">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/50">
#            Weltmuseum Wien
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Austria">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="austria" role="button" style="max-width:100% margin: 2px 0">
#            Austria
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="202" inst="Weltmuseum Wien" sort="count" val="202">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="202">
#           202
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/50" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="21.398305084745765" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:21.398305084745765%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_5 cat_13 cat_11 cat_4 cat_6 cat_14 cat_8 cat_3 cat_12 cat_18 cat_19 cat_16 cat_7 cat_0 main_unitedstates" row_id="49" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":54},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":32},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":31},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":27},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":20},{"DB_name":"Containers","DB_id":6,"DB_count":16},{"DB_name":"Staffs","DB_id":14,"DB_count":15},{"DB_name":"Figures","DB_id":8,"DB_count":13},{"DB_name":"Casting Materials","DB_id":3,"DB_count":11},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":11},{"DB_name":"Weaponry","DB_id":18,"DB_count":10},{"DB_name":"Heads","DB_id":19,"DB_count":7},{"DB_name":"Tools","DB_id":16,"DB_count":2},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":1}]'>
#        <div class="col-12 col-md-5" sort="museum" val="University of Pennsylvania Museum of Archaeology and Anthropology (Penn Museum)">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/49">
#            University of Pennsylvania Museum of Archaeology and Anthropology (Penn Museum)
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">
#            United States
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="188" inst="University of Pennsylvania Museum of Archaeology and Anthropology (Penn Museum)" sort="count" val="188">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="188">
#           188
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/49" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="19.915254237288135" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:19.915254237288135%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_12 cat_4 cat_8 cat_5 cat_6 cat_11 cat_19 cat_14 cat_13 cat_20 cat_7 cat_18 cat_17 cat_0 main_germany" row_id="24" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":45},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":36},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":30},{"DB_name":"Figures","DB_id":8,"DB_count":24},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":22},{"DB_name":"Containers","DB_id":6,"DB_count":21},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":16},{"DB_name":"Heads","DB_id":19,"DB_count":14},{"DB_name":"Staffs","DB_id":14,"DB_count":12},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":11},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":7},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":3},{"DB_name":"Weaponry","DB_id":18,"DB_count":3},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":2},{"DB_name":"Unassigned","DB_id":0,"DB_count":5}]'>
#        <div class="col-12 col-md-5" sort="museum" val="MARKK Museum am Rothenbaum Kulturen und Künste der Welt">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/24">
#            MARKK Museum am Rothenbaum Kulturen und Künste der Welt
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">
#            Germany
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="179" inst="MARKK Museum am Rothenbaum Kulturen und Künste der Welt" sort="count" val="179">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="179">
#           179
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/24" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="18.96186440677966" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:18.96186440677966%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_1 cat_5 cat_12 cat_19 cat_4 cat_6 cat_11 cat_14 cat_8 cat_13 cat_18 cat_0 main_unitedstates" row_id="22" test='[{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":105},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":66},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":50},{"DB_name":"Heads","DB_id":19,"DB_count":40},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":38},{"DB_name":"Containers","DB_id":6,"DB_count":36},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":34},{"DB_name":"Staffs","DB_id":14,"DB_count":34},{"DB_name":"Figures","DB_id":8,"DB_count":27},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":6},{"DB_name":"Weaponry","DB_id":18,"DB_count":2},{"DB_name":"Unassigned","DB_id":0,"DB_count":2}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Metropolitan Museum of Art">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/22">
#            Metropolitan Museum of Art
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">
#            United States
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="154" inst="Metropolitan Museum of Art" sort="count" val="154">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="154">
#           154
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/22" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="16.3135593220339" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:16.3135593220339%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_13 cat_5 cat_11 cat_1 cat_4 cat_6 cat_12 cat_16 cat_14 cat_7 cat_19 cat_18 cat_8 cat_20 cat_0 main_unitedkingdom" row_id="42" test='[{"DB_name":"Personal Adornment","DB_id":13,"DB_count":34},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":29},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":29},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":20},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":15},{"DB_name":"Containers","DB_id":6,"DB_count":14},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":13},{"DB_name":"Tools","DB_id":16,"DB_count":10},{"DB_name":"Staffs","DB_id":14,"DB_count":7},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":4},{"DB_name":"Heads","DB_id":19,"DB_count":4},{"DB_name":"Weaponry","DB_id":18,"DB_count":3},{"DB_name":"Figures","DB_id":8,"DB_count":2},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":4}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Pitt Rivers Museum">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/42">
#            Pitt Rivers Museum
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">
#            United Kingdom
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="148" inst="Pitt Rivers Museum" sort="count" val="148">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="148">
#           148
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/42" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="15.677966101694915" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:15.677966101694915%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_8 cat_1 cat_12 cat_13 cat_5 cat_11 cat_4 cat_14 cat_6 cat_19 cat_7 cat_20 cat_18 cat_10 cat_17 cat_0 main_netherlands" row_id="34" test='[{"DB_name":"Figures","DB_id":8,"DB_count":27},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":26},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":17},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":17},{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":13},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":9},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":8},{"DB_name":"Staffs","DB_id":14,"DB_count":7},{"DB_name":"Containers","DB_id":6,"DB_count":7},{"DB_name":"Heads","DB_id":19,"DB_count":7},{"DB_name":"Household &amp; Everyday Objects","DB_id":7,"DB_count":2},{"DB_name":"Contextual Objects: Beyond Benin","DB_id":20,"DB_count":2},{"DB_name":"Weaponry","DB_id":18,"DB_count":2},{"DB_name":"Healing &amp; Divining Objects","DB_id":10,"DB_count":1},{"DB_name":"Trade &amp; Exchange Goods","DB_id":17,"DB_count":1},{"DB_name":"Unassigned","DB_id":0,"DB_count":4}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Nationaal Museum van Wereldculturen and Wereldmuseum">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/34">
#            Nationaal Museum van Wereldculturen and Wereldmuseum
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Netherlands">
#         <div class="py-md-1">
#          <div class="d-flex flex-wrap">
#           <span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="netherlands" role="button" style="max-width:100% margin: 2px 0">
#            Netherlands
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-auto col-md-auto inst-col-count" count_default="122" inst="Nationaal Museum van Wereldculturen and Wereldmuseum" sort="count" val="122">
#         <div class="py-md-2 small fw-semibold text-end text-md-center">
#          <div class="d-inline object_count" count_default="122">
#           122
#          </div>
#          <div class="d-inline d-md-none">
#           Objects
#          </div>
#         </div>
#        </div>
#        <div class="col-12 col-md">
#         <div class="py-md-2">
#          <a class="progress position-relative" href="/institutions/34" style="height:35px">
#           <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="12.923728813559322" class="progress-bar overflow-visible" data-bs-title="" data-bs-toggle="tooltip" style="background-color:#0d6efd;width:12.923728813559322%;">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row g-2 g-md-0 gx-md-3 py-3 py-md-0 border-bottom sortable_elem div-hover align-items-center cat_5 cat_1 cat_13 cat_12 cat_11 cat_4 cat_8 cat_14 cat_19 cat_6 cat_18 main_germany" row_id="43" test='[{"DB_name":"Ceremonial Regalia","DB_id":5,"DB_count":24},{"DB_name":"Altar &amp; Shrine Objects","DB_id":1,"DB_count":23},{"DB_name":"Personal Adornment","DB_id":13,"DB_count":13},{"DB_name":"Palace Architecture &amp; Ornamentation","DB_id":12,"DB_count":11},{"DB_name":"Musical Instruments","DB_id":11,"DB_count":10},{"DB_name":"Ceremonial Objects","DB_id":4,"DB_count":9},{"DB_name":"Figures","DB_id":8,"DB_count":9},{"DB_name":"Staffs","DB_id":14,"DB_count":7},{"DB_name":"Heads","DB_id":19,"DB_count":6},{"DB_name":"Containers","DB_id":6,"DB_count":4},{"DB_name":"Weaponry","DB_id":18,"DB_count":1}]'>
#        <div class="col-12 col-md-5" sort="museum" val="Rautenstrauch-Joest-Museum">
#         <div class="py-md-2">
#          <div>
#           <a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/43">
#            Rautenstrauch-Joest-Museum
#           </a>
#          </div>
#         </div>
# ...
#          <div class="row">
#           <div class="col">
#            <div>
#             Ceremonial Objects
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             63
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="The term 'figure' loosely describes a range of different figurative sculptures known to have been cast and carved by Edo guilds. In a number of cases it is possible to identify who or what is being portrayed, in those cases the groupings are refined into separate groupings, such as: King Figures,... " filter_id="8" filter_name="Figures" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Figures
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             61
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="Staffs can be made from brass, bronze, iron, wood and ivory, or even a combination of different materials. Staffs have a variety of functions, some contain medicine, e.g. Osun Staffs. Some may only be used by individuals who have reached a certain office in the Edo socio-political hierarchy, or by... " filter_id="14" filter_name="Staffs" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Staffs
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             55
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="Various kinds of containers are known from the Kingdom of Benin. Many had specific ceremonial purposes, for example the Aquamanile which were used by the Oba to cleanse himself before certain ceremonies. Others may have been used to present gifts to the Oba or high-ranking chiefs. These tend to be... " filter_id="6" filter_name="Containers" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Containers
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             51
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="Within the category of ‘Heads’ all representations of human and animal heads can be viewed together. Unlike a bust, these objects do not depict the head, neck and shoulders, hence why the term ‘head’ rather than ‘bust’ has been used. Furthermore, not all of these heads may have been used for... " filter_id="19" filter_name="Heads" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Heads
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             77
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="Objects which may have been used by members of the court or titled office holders for a range of functions (i.e. functional, decorative) within their households. These are transportable and are not part of the palace architecture. Objects used to furnish and decorate interiors of palaces as well as... " filter_id="7" filter_name="Household &amp; Everyday Objects" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Household &amp; Everyday Objects
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             25
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="The Kingdom of Benin was for many centuries a military kingdom, conducting many expansion wars into the surrounding areas of West Africa. As such, a wide range of weaponry of various kinds and ages have been made and used by the Edo. A number of these reflect the international and highly connected... " filter_id="18" filter_name="Weaponry" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Weaponry
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             27
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="A number of objects which were used by members of different guilds - such as the Igbesanmwan, Igun-Ematon and the Igun-Eronmwon - to make objects are also part of museum collections today. Many of these are made from iron, illustrating the interconnected nature of palace guilds. From tongs to... " filter_id="16" filter_name="Tools" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Tools
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             12
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="The category of ‘Beyond Benin’ includes objects believed to have been made in the area known today as southern Nigeria based on stylistic and iconographic differences. These objects left the region before 1930. Some of these objects, specifically the brass and bronze pieces, are known in academia... " filter_id="20" filter_name="Contextual Objects: Beyond Benin" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Contextual Objects: Beyond Benin
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             16
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="In the late 15th century, Portuguese explorers reached the West African coastline and soon began trading with various Kingdoms along the coast and its hinterland. The Kingdom of Benin was one of these and quickly became an important trading partner due to the ready supplies of pepper, ivory and... " filter_id="17" filter_name="Trade &amp; Exchange Goods" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Trade &amp; Exchange Goods
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             10
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="The Benin-Portuguese Ivories made their way to Europe prior to 1897. It is believed that they were made by members of the Igbesanmwan but were commissioned by Europeans for European audiences and markets and not by the Ọba (Curnow, 1983[35]). These objects are separated from the main corpus... " filter_id="2" filter_name="Contextual Objects: Benin-Portuguese Ivories" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Contextual Objects: Benin-Portuguese Ivories
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             11
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="In addition to Tools used to make the lost-wax artworks themselves, a number of objects illustrating the technical sequence of lost-wax casting were acquired by European collectors during the early- to mid- 20th century. These 'sets' of objects were acquired by European collectors during discrete... " filter_id="3" filter_name="Casting Materials" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Casting Materials
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             4
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="Many of the textiles looted by the British in 1897 were made by the Owina n'Ida. Some of these were ceremonial regalia and garments worn by the Oba and high-ranking chiefs.
# " filter_id="15" filter_name="Textiles" filter_readmore="0">
#          <div class="row">
#           <div class="col">
#            <div>
#             Textiles
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             9
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="Objects used in healing and divining, often described as 'medicine'. These objects may be used by practitioners or priests, placed on altars and shrines, or worn by individuals for protection and good health. Osun, the Edo deity of medicine, is most commonly associated with objects of this kind.
#
#
# " filter_id="10" filter_name="Healing &amp; Divining Objects" filter_readmore="0">
#          <div class="row">
#           <div class="col">
#            <div>
#             Healing &amp; Divining Objects
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             9
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="cursor-pointer close-after-click list-group-item list-group-item-action filter_category" filter_desc="After Ọba Ovanramwen was removed from power and exiled by the British in 1897, the palace structures which organised the production of artworks in Benin City via the guild system were disrupted. In 1914 the interregnum ended and Ọba Eweka II was instated as Ọba of Benin; by 1927 the Benin... " filter_id="24" filter_name="Contextual Objects: Post-1930s" filter_readmore="1">
#          <div class="row">
#           <div class="col">
#            <div>
#             Contextual Objects: Post-1930s
#            </div>
#           </div>
#           <div class="col-auto">
#            <div>
#             4
#            </div>
#           </div>
#          </div>
#         </span>
#        </div>
#       </div>
#       <div class="modal-footer">
#        <button class="btn btn-dark filter_category" data-bs-dismiss="modal" filter_id="all" type="button">
#         Show all
#        </button>
#        <button class="btn btn-secondary" data-bs-dismiss="modal" type="button">
#         Close
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" aria-labelledby="modal_introductionLabel" class="modal fade" id="modal_introduction" tabindex="-1">
#     <div class="modal-dialog modal-lg modal-dialog-scrollable modal-dialog-centered">
#      <div class="modal-content">
#       <div class="modal-header">
#        <h5 class="modal-title" id="modal_introductionLabel">
#         Institutions
#        </h5>
#        <button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button">
#        </button>
#       </div>
#       <div class="modal-body">
#        <p style="white-space:pre-line;">
#         Study each institutional collection of Benin objects and sort the list of institutions by name, object count and country. Selecting an institution gives access to an introduction page with details about the institution, the collected data and an overview of object groups in the collection.
#        </p>
#        <p style="white-space:pre-line;">
#         The approach of preserving the structure and content of the digital material shared by the museums shows how each institution provides context for the objects. The Digital Benin-authored content in this space is labeled as such.
#        </p>
#       </div>
#       <div class="modal-footer">
#        <a class="btn btn-dark" href="/documentation/data-acquisition-and-data-management">
#         See documentation
#        </a>
#        <button class="btn btn-secondary" data-bs-dismiss="modal" type="button">
#         Close
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer class="footer mt-auto pt-5">
#    <div class="container-fluid py-3 bg-black text-light small">
#     <div class="row py-4">
#      <div class="col-12 col-md-3 text-center text-md-start">
#       <a href="/">
#        <img class="p-4 pt-0 w-100 pb-5" src="/data/digital_benin/media_global/footer/footer_logo.svg" style="max-width:200px"/>
#       </a>
#      </div>
#      <div class="col col-md-2">
#       <div class="pb-3 fw-bolder">
#        INFO
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none link-secondary" href="/eyo-oto">
#         Eyo Otọ
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/catalogue">
#         Catalogue
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/institutions">
#         Institutions
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/provenance">
#         Provenance
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/map">
#         Map
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/oral-history">
#         Oral history
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/itan-edo">
#         Itan Edo
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/media">
#         Media
#        </a>
#       </div>
#      </div>
#      <div class="col col-md-2">
#       <div class="pb-3 fw-bolder">
#        ABOUT
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/team">
#         Team
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/funding-and-host">
#         Funding &amp; host
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/documentation">
#         Documentation
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/bibliography">
#         Bibliography
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/media">
#         Media
#        </a>
#       </div>
#      </div>
#      <div class="col col-md-2">
#       <div class="pb-3 fw-bolder">
#        OTHER
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/data-privacy-policy">
#         Data privacy policy
#        </a>
#       </div>
#       <div>
#        <a class="link-secondary text-decoration-none" href="/imprint">
#         Imprint
#        </a>
#       </div>
#      </div>
#      <div class="col-12 col-md-3">
#       <div class="pt-4 pt-md-1 text-center scrolltotop cursor-pointer">
#        <img class="pb-4" src="/data/digital_benin/media_global/footer/back_to_top.svg" style="max-width:60px"/>
#        <div class="fw-bolder">
#         BACK TO TOP
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#  </body>
# </html>

# %%
## is this a bs4?

type(soup)
# Out:
# bs4.BeautifulSoup

# %%
## finding the div with the sort, museum?

soup.find_all("div", sort ="museum")
# Out:
# [<div class="col-12 col-md-5" sort="museum" val="British Museum"><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/5">British Museum</a></div></div></div>,
#  <div class="col-12 col-md-5" sort="museum" val="Ethnologisches Museum, Staatliche Museen zu Berlin"><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/13">Ethnologisches Museum, Staatliche Museen zu Berlin</a></div></div></div>,
#  <div class="col-12 col-md-5" sort="museum" val="Field Museum"><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/15">Field Museum</a></div></div></div>,
#  <div class="col-12 col-md-5" sort="museum" val="Museum of Archaeology and Anthropology, University of Cambridge"><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/28">Museum of Archaeology and Anthropology, University of Cambridge</a></div></div></div>,
#  <div class="col-12 col-md-5" sort="museum" val="National Museum, Benin"><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/36">National Museum, Benin</a></div></div></div>,
#  <div class="col-12 col-md-5" sort="museum" val="Staatliche Ethnographische Sammlungen Sachsen und Staatliche Kunstsammlungen Dresden"><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions
><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/109">Hood Museum of Art</a></div></div></div>,
#  <div class="col-12 col-md-5" sort="museum" val="Phoebe A. Hearst Museum of Anthropology, University of California at Berkeley"><div class="py-md-2"><div><a class="link-dark fs-5 fw-semibold text-decoration-none" href="/institutions/100">Phoebe A. Hearst Museum of Anthropology, University of California at Berkeley</a></div></div></div>]

# %%
## trying to get museum names

for name in museums:
    print(name.get_text())
    print("*******")
# Out:
# British Museum
# *******
# Ethnologisches Museum, Staatliche Museen zu Berlin
# *******
# Field Museum
# *******
# Museum of Archaeology and Anthropology, University of Cambridge
# *******
# National Museum, Benin
# *******
# Staatliche Ethnographische Sammlungen Sachsen und Staatliche Kunstsammlungen Dresden
# *******
# Weltmuseum Wien
# *******
# University of Pennsylvania Museum of Archaeology and Anthropology (Penn Museum)
# *******
# MARKK Museum am Rothenbaum Kulturen und Künste der Welt
# *******
# Metropolitan Museum of Art
# *******
# Pitt Rivers Museum
# *******
# Nationaal Museum van Wereldculturen and Wereldmuseum
# *******
# Rautenstrauch-Joest-Museum
# *******
# National Museum, Lagos
# *******
# National Museums Scotland
# *******
# Horniman Museum and Gardens
# *******
# National Museums Liverpool, World Museum
# *******
# Linden-Museum Stuttgart, Staatliches Museum für Völkerkunde
# *******
# Fowler Museum at UCLA
# *******
# Weltkulturen Museum Frankfurt am Main
# *******
# Världskultur Museerna, National Museums of World Culture
# *******
# American Museum of Natural History
# *******
# National Museum of Ireland
# *******
# Peabody Museum of Archaeology and Ethnology at Harvard University
# *******
# Smithsonian National Museum of African Art
# *******
# musée du quai Branly - Jacques Chirac
# *******
# Glasgow Museums (Kelvingrove Art Gallery and Museum)
# *******
# Reiss-Engelhorn-Museen, Museum Weltkulturen
# *******
# Peter the Great Museum of Anthropology and Ethnography (the Kunstkamera)
# *******
# Museum Fünf Kontinente, Staatliche Museen in Bayern
# *******
# Brooklyn Museum
# *******
# Manchester Museum
# *******
# UiO, Museum of Cultural History, University of Oslo
# *******
# Museum der Kulturen Basel
# *******
# Royal Pavilion & Museums Trust
# *******
# Übersee-Museum Bremen
# *******
# Völkerkundemuseum der Universität Zürich
# *******
# Smithsonian National Museum of Natural History
# *******
# Canterbury Museum
# *******
# Indianapolis Museum of Art at Newfields
# *******
# Museum Rietberg Zürich
# *******
# Science Museum
# *******
# Powell-Cotton Museum
# *******
# Seattle Art Museum
# *******
# Ipswich Museum
# *******
# Städtische Museen Freiburg
# *******
# The Israel Museum
# *******
# National Gallery of Australia
# *******
# Völkerkundesammlung
# *******
# Sainsbury Centre for Visual Arts
# *******
# Cleveland Museum of Art
# *******
# New Orleans Museum of Art
# *******
# Research and Cultural Collections, University of Birmingham
# *******
# Historisches und Völkerkundemuseum St. Gallen
# *******
# Art Institute of Chicago
# *******
# Museum of Fine Arts, Boston
# *******
# Musée d'Ethnographie de Genève
# *******
# Sidney and Lois Eskenazi Museum of Art
# *******
# Buffalo Museum of Sciences
# *******
# Stanley Museum of Art, University of Iowa
# *******
# Detroit Institute of Arts
# *******
# North Carolina Museum of Art
# *******
# Nationalmuseet, National Museum of Denmark
# *******
# Musée des beaux-arts
# *******
# Museum Ulm
# *******
# Städtisches Museum Braunschweig
# *******
# Dallas Museum of Art
# *******
# Royal Ontario Museum
# *******
#  'Weltmuseum Wien',
#  'University of Pennsylvania Museum of Archaeology and Anthropology (Penn Museum)',
#  'MARKK Museum am Rothenbaum Kulturen und Künste der Welt',
#  'Metropolitan Museum of Art',
#  'Pitt Rivers Museum',
#  'Nationaal Museum van Wereldculturen and Wereldmuseum',
#  'Rautenstrauch-Joest-Museum',
#  'National Museum, Lagos',
#  'National Museums Scotland',
#  'Horniman Museum and Gardens',
#  'National Museums Liverpool, World Museum',
#  'Linden-Museum Stuttgart, Staatliches Museum für Völkerkunde',
#  'Fowler Museum at UCLA',
#  'Weltkulturen Museum Frankfurt am Main',
#  'Världskultur Museerna, National Museums of World Culture',
#  'American Museum of Natural History',
#  'National Museum of Ireland',
#  'Peabody Museum of Archaeology and Ethnology at Harvard University',
#  'Smithsonian National Museum of African Art',
#  'musée du quai Branly - Jacques Chirac',
#  'Glasgow Museums (Kelvingrove Art Gallery and Museum)',
#  'Reiss-Engelhorn-Museen, Museum Weltkulturen',
#  'Peter the Great Museum of Anthropology and Ethnography (the Kunstkamera)',
#  'Museum Fünf Kontinente, Staatliche Museen in Bayern',
#  'Brooklyn Museum',
#  'Manchester Museum',
#  'UiO, Museum of Cultural History, University of Oslo',
#  'Museum der Kulturen Basel',
#  'Royal Pavilion & Museums Trust',
#  'Übersee-Museum Bremen',
#  'Völkerkundemuseum der Universität Zürich',
#  'Smithsonian National Museum of Natural History',
#  'Canterbury Museum',
#  'Indianapolis Museum of Art at Newfields',
#  'Museum Rietberg Zürich',
#  'Science Museum',
#  'Powell-Cotton Museum',
#  'Seattle Art Museum',
#  'Ipswich Museum',
#  'Städtische Museen Freiburg',
#  'The Israel Museum',
#  'National Gallery of Australia',
#  'Völkerkundesammlung',
#  'Sainsbury Centre for Visual Arts',
#  'Cleveland Museum of Art',
#  'New Orleans Museum of Art',
#  'Research and Cultural Collections, University of Birmingham',
#  'Historisches und Völkerkundemuseum St. Gallen',
#  'Art Institute of Chicago',
#  'Museum of Fine Arts, Boston',
#  "Musée d'Ethnographie de Genève",
#  'Sidney and Lois Eskenazi Museum of Art',
#  'Buffalo Museum of Sciences',
#  'Stanley Museum of Art, University of Iowa',
#  'Detroit Institute of Arts',
#  'North Carolina Museum of Art',
#  'Nationalmuseet, National Museum of Denmark',
#  'Musée des beaux-arts',
#  'Museum Ulm',
#  'Städtisches Museum Braunschweig',
#  'Dallas Museum of Art',
#  'Royal Ontario Museum',
#  'Princeton University Art Museum',
#  'AfricaMuseum, Royal Museum for Central Africa',
#  'MIM Musical Instrument Museum',
#  'South Australian Museum',
#  'Roemer- und Pelizaeus-Museum Hildesheim',
#  'Royal Albert Memorial Museum & Art Gallery (RAMM)',
#  'Royal Museums Greenwich',
#  'Royal Armouries',
#  'Patricia & Phillip Frost Art Museum, Florida International University',
#  'SLAM, Saint Louis Art Museum',
#  'Davis Museum at Wellesley College',
#  'Barnes Foundation',
#  'Nelson-Atkins Museum of Art',
#  'Bernisches Historisches Museum',
#  'Baltimore Museum of Art',
#  'Sam Noble Oklahoma Museum of Natural History (formerly Stovall Museum)',
#  'Minneapolis Institute of Arts',
#  'Denver Art Museum',
#  'de Young museum',
#  'Royal Collection Trust',
#  'Warrington Museum and Art Gallery',
#  'Calderdale Museums, Bankfield Museum',
#  'Birmingham Museums Trust',
#  'Yale University Art Gallery',
#  'Bristol Museum & Art Gallery',
#  'Krannert Art Museum | University of Illinois at Urbana-Champaign',
#  'Harvard Art Museums',
#  'Museum aan de Stroom',
#  'HMA, Haffenreffer Museum of Anthropology at Brown University',
#  'Museums and Special Collections, University of Aberdeen',
#  'Great North Museum: Hancock',
#  'Hull Museums',
#  'Niedersächsische Landesmuseen Oldenburg, Landesmuseum Natur und Mensch Oldenburg',
#  'Speed Art Museum',
#  'Al Thani Collection',
#  'Northampton Museums and Art Gallery',
#  'Toledo Museum of Art',
#  'Musée de la musique, Cité de la Musique - Philharmonie de Paris',
#  'National Archives, John F. Kennedy Presidential Library and Museum',
#  'Muzeum Narodowe w Szczecinie',
#  'VMFA, Virginia Museum of Fine Arts',
#  'Barber Institute of Fine Arts',
#  'Museu Nacional de Etnologia',
#  'Musée national Picasso Paris',
#  'National Gallery of Art',
#  'Museum Folkwang',
#  'Michael C. Carlos Museum, Emory University',
#  'Fleming Museum of Art, University of Vermont',
#  "Musée d'Ethnographie de Neuchâtel",
#  'Gustavianum - Uppsala University Museum',
#  'Hunt Museum',
#  'Museum of Anthropology at UBC',
#  'Institut für Ethnologie und Afrikastudien, Johannes Gutenberg-Universität Mainz',
#  'Canadian Museum of History / Musée canadien de l’histoire',
#  'Landesmuseum Hannover, Das WeltenMuseum',
#  'Institut für Ethnologie und Ethnologische Sammlung der Universität Göttingen',
#  'RISD Museum, Museum of Art at Rhode Island School of Design',
#  'Carnegie Museum of Art',
#  'Allen Memorial Art Museum, Oberlin College',
#  'Newark Museum of Art',
#  'LACMA The Los Angeles County Museum of Art',
#  'Hood Museum of Art',
#  'Phoebe A. Hearst Museum of Anthropology, University of California at Berkeley']

# %%
## did i get the length right?

len(museum_names)
# Out:
# 131

# %%
## now for country name
soup.find_all("div", sort ="filter_main")
# Out:
# [<div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Nigeria"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="nigeria" role="button" style="max-width:100% margin: 2px 0">Nigeria</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Austria"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="austria" role="button" style="max-width:100% margin: 2px 0">Austria</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Netherlands"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="netherlands" role="button" style="max-width:100% margin: 2px 0">Netherlands</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Nigeria"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="nigeria" role="button" style="max-width:100% margin: 2px 0">Nigeria</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Sweden"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="sweden" role="button" style="max-width:100% margin: 2px 0">Sweden</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Ireland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="ireland" role="button" style="max-width:100% margin: 2px 0">Ireland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="France"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="france" role="button" style="max-width:100% margin: 2px 0">France</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Russia"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="russia" role="button" style="max-width:100% margin: 2px 0">Russia</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Norway"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="norway" role="button" style="max-width:100% margin: 2px 0">Norway</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Switzerland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="switzerland" role="button" style="max-width:100% margin: 2px 0">Switzerland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Switzerland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="switzerland" role="button" style="max-width:100% margin: 2px 0">Switzerland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="New Zealand"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="newzealand" role="button" style="max-width:100% margin: 2px 0">New Zealand</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Switzerland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="switzerland" role="button" style="max-width:100% margin: 2px 0">Switzerland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Israel"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="israel" role="button" style="max-width:100% margin: 2px 0">Israel</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Australia"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="australia" role="button" style="max-width:100% margin: 2px 0">Australia</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Switzerland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="switzerland" role="button" style="max-width:100% margin: 2px 0">Switzerland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Switzerland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="switzerland" role="button" style="max-width:100% margin: 2px 0">Switzerland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Denmark"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="denmark" role="button" style="max-width:100% margin: 2px 0">Denmark</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Canada"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="canada" role="button" style="max-width:100% margin: 2px 0">Canada</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Canada"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="canada" role="button" style="max-width:100% margin: 2px 0">Canada</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Belgium"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="belgium" role="button" style="max-width:100% margin: 2px 0">Belgium</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Belgium"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="belgium" role="button" style="max-width:100% margin: 2px 0">Belgium</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Australia"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="australia" role="button" style="max-width:100% margin: 2px 0">Australia</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Switzerland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="switzerland" role="button" style="max-width:100% margin: 2px 0">Switzerland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Belgium"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="belgium" role="button" style="max-width:100% margin: 2px 0">Belgium</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="France"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="france" role="button" style="max-width:100% margin: 2px 0">France</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="France"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="france" role="button" style="max-width:100% margin: 2px 0">France</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Poland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="poland" role="button" style="max-width:100% margin: 2px 0">Poland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United Kingdom"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedkingdom" role="button" style="max-width:100% margin: 2px 0">United Kingdom</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Portugal"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="portugal" role="button" style="max-width:100% margin: 2px 0">Portugal</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="France"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="france" role="button" style="max-width:100% margin: 2px 0">France</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Switzerland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="switzerland" role="button" style="max-width:100% margin: 2px 0">Switzerland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Sweden"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="sweden" role="button" style="max-width:100% margin: 2px 0">Sweden</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Ireland"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="ireland" role="button" style="max-width:100% margin: 2px 0">Ireland</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Canada"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="canada" role="button" style="max-width:100% margin: 2px 0">Canada</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Canada"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="canada" role="button" style="max-width:100% margin: 2px 0">Canada</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="Germany"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="germany" role="button" style="max-width:100% margin: 2px 0">Germany</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>,
#  <div class="col col-md-auto inst-col-filter" sort="filter_main" val="United States"><div class="py-md-1"><div class="d-flex flex-wrap"><span class="text-truncate nav-link filter_main badge text-bg-dark" filter_id="unitedstates" role="button" style="max-width:100% margin: 2px 0">United States</span></div></div></div>]

# %%
countries = soup.find_all("div", sort ="filter_main")

# %%
## make it into a list

countries = [(country.get_text()) for country in countries]
countries
# Out:
# ['United Kingdom',
#  'Germany',
#  'United States',
#  'United Kingdom',
#  'Nigeria',
#  'Germany',
#  'Austria',
#  'United States',
#  'Germany',
#  'United States',
#  'United Kingdom',
#  'Netherlands',
#  'Germany',
#  'Nigeria',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'Germany',
#  'United States',
#  'Germany',
#  'Sweden',
#  'United States',
#  'Ireland',
#  'United States',
#  'United States',
#  'France',
#  'United Kingdom',
#  'Germany',
#  'Russia',
#  'Germany',
#  'United States',
#  'United Kingdom',
#  'Norway',
#  'Switzerland',
#  'United Kingdom',
#  'Germany',
#  'Switzerland',
#  'United States',
#  'New Zealand',
#  'United States',
#  'Switzerland',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'United Kingdom',
#  'Germany',
#  'Israel',
#  'Australia',
#  'Germany',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'Switzerland',
#  'United States',
#  'United States',
#  'Switzerland',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Denmark',
#  'Canada',
#  'Germany',
#  'Germany',
#  'United States',
#  'Canada',
#  'United States',
#  'Belgium',
#  'Belgium',
#  'Australia',
#  'Germany',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Switzerland',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'Belgium',
#  'United States',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'Germany',
#  'United States',
#  'France',
#  'United Kingdom',
#  'United States',
#  'France',
#  'United States',
#  'Poland',
#  'United States',
#  'United Kingdom',
#  'Portugal',
#  'France',
#  'United States',
#  'Germany',
#  'United States',
#  'United States',
#  'Switzerland',
#  'Sweden',
#  'Ireland',
#  'Canada',
#  'Germany',
#  'Canada',
#  'Germany',
#  'Germany',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States']

# %%
len(countries)
# Out:
# 131

# %%
objects = [soup.find_all("div", sort ="count")]
objects
# Out:
# [[<div class="col-auto col-md-auto inst-col-count" count_default="944" inst="British Museum" sort="count" val="944"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="944">944</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="518" inst="Ethnologisches Museum, Staatliche Museen zu Berlin" sort="count" val="518"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="518">518</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="393" inst="Field Museum" sort="count" val="393"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="393">393</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="350" inst="Museum of Archaeology and Anthropology, University of Cambridge" sort="count" val="350"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="350">350</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="285" inst="National Museum, Benin" sort="count" val="285"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="285">285</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="283" inst="Staatliche Ethnographische Sammlungen Sachsen und Staatliche Kunstsammlungen Dresden" sort="count" val="283"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="283">283</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="202" inst="Weltmuseum Wien" sort="count" val="202"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="202">202</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="188" inst="University of Pennsylvania Museum of Archaeology and Anthropology (Penn Museum)" sort="count" val="188"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="188">188</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="179" inst="MARKK Museum am Rothenbaum Kulturen und Künste der Welt" sort="count" val="179"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="179">179</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="154" inst="Metropolitan Museum of Art" sort="count" val="154"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="154">154</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="148" inst="Pitt Rivers Museum" sort="count" val="148"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="148">148</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="122" inst="Nationaal Museum van Wereldculturen and Wereldmuseum" sort="count" val="122"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="122">122</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="92" inst="Rautenstrauch-Joest-Museum" sort="count" val="92"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="92">92</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="81" inst="National Museum, Lagos" sort="count" val="81"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="81">81</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="74" inst="National Museums Scotland" sort="count" val="74"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="74">74</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="72" inst="Horniman Museum and Gardens" sort="count" val="72"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="72">72</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="71" inst="National Museums Liverpool, World Museum" sort="count" val="71"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="71">71</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="69" inst="Linden-Museum Stuttgart, Staatliches Museum für Völkerkunde" sort="count" val="69"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="69">69</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="64" inst="Fowler Museum at UCLA" sort="count" val="64"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="64">64</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="55" inst="Weltkulturen Museum Frankfurt am Main" sort="count" val="55"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="55">55</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="53" inst="Världskultur Museerna, National Museums of World Culture" sort="count" val="53"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="53">53</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="48" inst="American Museum of Natural History" sort="count" val="48"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="48">48</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="46" inst="National Museum of Ireland" sort="count" val="46"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="46">46</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="43" inst="Peabody Museum of Archaeology and Ethnology at Harvard University" sort="count" val="43"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="43">43</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="37" inst="Smithsonian National Museum of African Art" sort="count" val="37"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="37">37</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="35" inst="musée du quai Branly - Jacques Chirac" sort="count" val="35"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="35">35</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="32" inst="Glasgow Museums (Kelvingrove Art Gallery and Museum)" sort="count" val="32"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="32">32</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="32" inst="Reiss-Engelhorn-Museen, Museum Weltkulturen" sort="count" val="32"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="32">32</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="28" inst="Peter the Great Museum of Anthropology and Ethnography (the Kunstkamera)" sort="count" val="28"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="28">28</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="24" inst="Museum Fünf Kontinente, Staatliche Museen in Bayern" sort="count" val="24"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="24">24</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="23" inst="Brooklyn Museum" sort="count" val="23"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="23">23</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="23" inst="Manchester Museum" sort="count" val="23"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="23">23</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="23" inst="UiO, Museum of Cultural History, University of Oslo" sort="count" val="23"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="23">23</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="20" inst="Museum der Kulturen Basel" sort="count" val="20"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="20">20</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="18" inst="Royal Pavilion &amp; Museums Trust" sort="count" val="18"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="18">18</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="18" inst="Übersee-Museum Bremen" sort="count" val="18"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="18">18</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="17" inst="Völkerkundemuseum der Universität Zürich" sort="count" val="17"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="17">17</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="16" inst="Smithsonian National Museum of Natural History" sort="count" val="16"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="16">16</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="15" inst="Canterbury Museum" sort="count" val="15"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="15">15</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="15" inst="Indianapolis Museum of Art at Newfields" sort="count" val="15"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="15">15</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="14" inst="Museum Rietberg Zürich" sort="count" val="14"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="14">14</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="14" inst="Science Museum" sort="count" val="14"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="14">14</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="13" inst="Powell-Cotton Museum" sort="count" val="13"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="13">13</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="12" inst="Seattle Art Museum" sort="count" val="12"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="12">12</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="10" inst="Ipswich Museum" sort="count" val="10"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="10">10</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="10" inst="Städtische Museen Freiburg" sort="count" val="10"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="10">10</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="9" inst="The Israel Museum" sort="count" val="9"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="9">9</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="9" inst="National Gallery of Australia" sort="count" val="9"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="9">9</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="9" inst="Völkerkundesammlung" sort="count" val="9"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="9">9</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="8" inst="Sainsbury Centre for Visual Arts" sort="count" val="8"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="8">8</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="8" inst="Cleveland Museum of Art" sort="count" val="8"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="8">8</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="8" inst="New Orleans Museum of Art" sort="count" val="8"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="8">8</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="8" inst="Research and Cultural Collections, University of Birmingham" sort="count" val="8"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="8">8</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="8" inst="Historisches und Völkerkundemuseum St. Gallen" sort="count" val="8"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="8">8</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="7" inst="Art Institute of Chicago" sort="count" val="7"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="7">7</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="7" inst="Museum of Fine Arts, Boston" sort="count" val="7"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="7">7</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="7" inst="Musée d'Ethnographie de Genève" sort="count" val="7"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="7">7</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="7" inst="Sidney and Lois Eskenazi Museum of Art" sort="count" val="7"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="7">7</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="7" inst="Buffalo Museum of Sciences" sort="count" val="7"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="7">7</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="6" inst="Stanley Museum of Art, University of Iowa" sort="count" val="6"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="6">6</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="6" inst="Detroit Institute of Arts" sort="count" val="6"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="6">6</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="5" inst="North Carolina Museum of Art" sort="count" val="5"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="5">5</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="5" inst="Nationalmuseet, National Museum of Denmark" sort="count" val="5"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="5">5</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="5" inst="Musée des beaux-arts" sort="count" val="5"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="5">5</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="5" inst="Museum Ulm" sort="count" val="5"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="5">5</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="5" inst="Städtisches Museum Braunschweig" sort="count" val="5"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="5">5</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="4" inst="Dallas Museum of Art" sort="count" val="4"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="4">4</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="4" inst="Royal Ontario Museum" sort="count" val="4"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="4">4</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="4" inst="Princeton University Art Museum" sort="count" val="4"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="4">4</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="4" inst="AfricaMuseum, Royal Museum for Central Africa" sort="count" val="4"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="4">4</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="4" inst="MIM Musical Instrument Museum" sort="count" val="4"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="4">4</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="4" inst="South Australian Museum" sort="count" val="4"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="4">4</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="4" inst="Roemer- und Pelizaeus-Museum Hildesheim" sort="count" val="4"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="4">4</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Royal Albert Memorial Museum &amp; Art Gallery (RAMM)" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Royal Museums Greenwich" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Royal Armouries" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Patricia &amp; Phillip Frost Art Museum, Florida International University" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="SLAM, Saint Louis Art Museum" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Davis Museum at Wellesley College" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Barnes Foundation" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Nelson-Atkins Museum of Art" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Bernisches Historisches Museum" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Baltimore Museum of Art" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Sam Noble Oklahoma Museum of Natural History (formerly Stovall Museum)" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Minneapolis Institute of Arts" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="Denver Art Museum" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="3" inst="de Young museum" sort="count" val="3"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="3">3</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Royal Collection Trust" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Warrington Museum and Art Gallery" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Calderdale Museums, Bankfield Museum" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Birmingham Museums Trust" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Yale University Art Gallery" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Bristol Museum &amp; Art Gallery" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Krannert Art Museum | University of Illinois at Urbana-Champaign" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Harvard Art Museums" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="Museum aan de Stroom" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="2" inst="HMA, Haffenreffer Museum of Anthropology at Brown University" sort="count" val="2"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="2">2</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Museums and Special Collections, University of Aberdeen" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Great North Museum: Hancock" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Hull Museums" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Niedersächsische Landesmuseen Oldenburg, Landesmuseum Natur und Mensch Oldenburg" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Speed Art Museum" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Al Thani Collection" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Northampton Museums and Art Gallery" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Toledo Museum of Art" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Musée de la musique, Cité de la Musique - Philharmonie de Paris" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="National Archives, John F. Kennedy Presidential Library and Museum" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Muzeum Narodowe w Szczecinie" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="VMFA, Virginia Museum of Fine Arts" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Barber Institute of Fine Arts" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Museu Nacional de Etnologia" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Musée national Picasso Paris" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="National Gallery of Art" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Museum Folkwang" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Michael C. Carlos Museum, Emory University" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Fleming Museum of Art, University of Vermont" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Musée d'Ethnographie de Neuchâtel" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Gustavianum - Uppsala University Museum" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Hunt Museum" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Museum of Anthropology at UBC" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Institut für Ethnologie und Afrikastudien, Johannes Gutenberg-Universität Mainz" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Canadian Museum of History / Musée canadien de l’histoire" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Landesmuseum Hannover, Das WeltenMuseum" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Institut für Ethnologie und Ethnologische Sammlung der Universität Göttingen" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="RISD Museum, Museum of Art at Rhode Island School of Design" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Carnegie Museum of Art" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Allen Memorial Art Museum, Oberlin College" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Newark Museum of Art" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="LACMA The Los Angeles County Museum of Art" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Hood Museum of Art" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>,
#   <div class="col-auto col-md-auto inst-col-count" count_default="1" inst="Phoebe A. Hearst Museum of Anthropology, University of California at Berkeley" sort="count" val="1"><div class="py-md-2 small fw-semibold text-end text-md-center"><div class="d-inline object_count" count_default="1">1</div><div class="d-inline d-md-none"> Objects</div></div></div>]]

# %%
objects = [(number.get_text()) for number in objects]
objects
## did this not work because the number and the objects are in two different divs? I do not know, i've tried
## other classes and it still doesn't work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/s2/yhgvwy5j2nj1j2xfcsx5gwp00000gn/T/ipykernel_4134/1884560748.py in <module>
# ----> 1 objects = [(number.get_text()) for number in objects]
#       2 objects
#
# /var/folders/s2/yhgvwy5j2nj1j2xfcsx5gwp00000gn/T/ipykernel_4134/1884560748.py in <listcomp>(.0)
# ----> 1 objects = [(number.get_text()) for number in objects]
#       2 objects
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py in __getattr__(self, key)
#    2287     def __getattr__(self, key):
#    2288         """Raise a helpful exception to explain a common code fix."""
# -> 2289         raise AttributeError(
#    2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
museum_list = []

for item in zip(museum_names, countries):
    museum_list.append(item)

museum_list
# Out:
# [('British Museum', 'United Kingdom'),
#  ('Ethnologisches Museum, Staatliche Museen zu Berlin', 'Germany'),
#  ('Field Museum', 'United States'),
#  ('Museum of Archaeology and Anthropology, University of Cambridge',
#   'United Kingdom'),
#  ('National Museum, Benin', 'Nigeria'),
#  ('Staatliche Ethnographische Sammlungen Sachsen und Staatliche Kunstsammlungen Dresden',
#   'Germany'),
#  ('Weltmuseum Wien', 'Austria'),
#  ('University of Pennsylvania Museum of Archaeology and Anthropology (Penn Museum)',
#   'United States'),
#  ('MARKK Museum am Rothenbaum Kulturen und Künste der Welt', 'Germany'),
#  ('Metropolitan Museum of Art', 'United States'),
#  ('Pitt Rivers Museum', 'United Kingdom'),
#  ('Nationaal Museum van Wereldculturen and Wereldmuseum', 'Netherlands'),
#  ('Rautenstrauch-Joest-Museum', 'Germany'),
#  ('National Museum, Lagos', 'Nigeria'),
#  ('National Museums Scotland', 'United Kingdom'),
#  ('Horniman Museum and Gardens', 'United Kingdom'),
#  ('National Museums Liverpool, World Museum', 'United Kingdom'),
#  ('Linden-Museum Stuttgart, Staatliches Museum für Völkerkunde', 'Germany'),
#  ('Fowler Museum at UCLA', 'United States'),
#  ('Weltkulturen Museum Frankfurt am Main', 'Germany'),
#  ('Världskultur Museerna, National Museums of World Culture', 'Sweden'),
#  ('American Museum of Natural History', 'United States'),
#  ('National Museum of Ireland', 'Ireland'),
#  ('Peabody Museum of Archaeology and Ethnology at Harvard University',
#   'United States'),
#  ('Smithsonian National Museum of African Art', 'United States'),
#  ('musée du quai Branly - Jacques Chirac', 'France'),
#  ('Glasgow Museums (Kelvingrove Art Gallery and Museum)', 'United Kingdom'),
#  ('Reiss-Engelhorn-Museen, Museum Weltkulturen', 'Germany'),
#  ('Peter the Great Museum of Anthropology and Ethnography (the Kunstkamera)',
#   'Russia'),
#  ('Museum Fünf Kontinente, Staatliche Museen in Bayern', 'Germany'),
#  ('Brooklyn Museum', 'United States'),
#  ('Manchester Museum', 'United Kingdom'),
#  ('UiO, Museum of Cultural History, University of Oslo', 'Norway'),
#  ('Museum der Kulturen Basel', 'Switzerland'),
#  ('Royal Pavilion & Museums Trust', 'United Kingdom'),
#  ('Übersee-Museum Bremen', 'Germany'),
#  ('Völkerkundemuseum der Universität Zürich', 'Switzerland'),
#  ('Smithsonian National Museum of Natural History', 'United States'),
#  ('Canterbury Museum', 'New Zealand'),
#  ('Indianapolis Museum of Art at Newfields', 'United States'),
#  ('Museum Rietberg Zürich', 'Switzerland'),
#  ('Science Museum', 'United Kingdom'),
#  ('Powell-Cotton Museum', 'United Kingdom'),
#  ('Seattle Art Museum', 'United States'),
#  ('Ipswich Museum', 'United Kingdom'),
#  ('Städtische Museen Freiburg', 'Germany'),
#  ('The Israel Museum', 'Israel'),
#  ('National Gallery of Australia', 'Australia'),
#  ('Völkerkundesammlung', 'Germany'),
#  ('Sainsbury Centre for Visual Arts', 'United Kingdom'),
#  ('Cleveland Museum of Art', 'United States'),
#  ('New Orleans Museum of Art', 'United States'),
#  ('Research and Cultural Collections, University of Birmingham',
#   'United Kingdom'),
#  ('Historisches und Völkerkundemuseum St. Gallen', 'Switzerland'),
#  ('Art Institute of Chicago', 'United States'),
#  ('Museum of Fine Arts, Boston', 'United States'),
#  ("Musée d'Ethnographie de Genève", 'Switzerland'),
#  ('Sidney and Lois Eskenazi Museum of Art', 'United States'),
#  ('Buffalo Museum of Sciences', 'United States'),
#  ('Stanley Museum of Art, University of Iowa', 'United States'),
#  ('Detroit Institute of Arts', 'United States'),
#  ('North Carolina Museum of Art', 'United States'),
#  ('Nationalmuseet, National Museum of Denmark', 'Denmark'),
#  ('Musée des beaux-arts', 'Canada'),
#  ('Museum Ulm', 'Germany'),
#  ('Städtisches Museum Braunschweig', 'Germany'),
#  ('Dallas Museum of Art', 'United States'),
#  ('Royal Ontario Museum', 'Canada'),
#  ('Princeton University Art Museum', 'United States'),
#  ('AfricaMuseum, Royal Museum for Central Africa', 'Belgium'),
#  ('MIM Musical Instrument Museum', 'Belgium'),
#  ('South Australian Museum', 'Australia'),
#  ('Roemer- und Pelizaeus-Museum Hildesheim', 'Germany'),
#  ('Royal Albert Memorial Museum & Art Gallery (RAMM)', 'United Kingdom'),
#  ('Royal Museums Greenwich', 'United Kingdom'),
#  ('Royal Armouries', 'United Kingdom'),
#  ('Patricia & Phillip Frost Art Museum, Florida International University',
#   'United States'),
#  ('SLAM, Saint Louis Art Museum', 'United States'),
#  ('Davis Museum at Wellesley College', 'United States'),
#  ('Barnes Foundation', 'United States'),
#  ('Nelson-Atkins Museum of Art', 'United States'),
#  ('Bernisches Historisches Museum', 'Switzerland'),
#  ('Baltimore Museum of Art', 'United States'),
#  ('Sam Noble Oklahoma Museum of Natural History (formerly Stovall Museum)',
#   'United States'),
#  ('Minneapolis Institute of Arts', 'United States'),
#  ('Denver Art Museum', 'United States'),
#  ('de Young museum', 'United States'),
#  ('Royal Collection Trust', 'United Kingdom'),
#  ('Warrington Museum and Art Gallery', 'United Kingdom'),
#  ('Calderdale Museums, Bankfield Museum', 'United Kingdom'),
#  ('Birmingham Museums Trust', 'United Kingdom'),
#  ('Yale University Art Gallery', 'United States'),
#  ('Bristol Museum & Art Gallery', 'United Kingdom'),
#  ('Krannert Art Museum | University of Illinois at Urbana-Champaign',
#   'United States'),
#  ('Harvard Art Museums', 'United States'),
#  ('Museum aan de Stroom', 'Belgium'),
#  ('HMA, Haffenreffer Museum of Anthropology at Brown University',
#   'United States'),
#  ('Museums and Special Collections, University of Aberdeen', 'United Kingdom'),
#  ('Great North Museum: Hancock', 'United Kingdom'),
#  ('Hull Museums', 'United Kingdom'),
#  ('Niedersächsische Landesmuseen Oldenburg, Landesmuseum Natur und Mensch Oldenburg',
#   'Germany'),
#  ('Speed Art Museum', 'United States'),
#  ('Al Thani Collection', 'France'),
#  ('Northampton Museums and Art Gallery', 'United Kingdom'),
#  ('Toledo Museum of Art', 'United States'),
#  ('Musée de la musique, Cité de la Musique - Philharmonie de Paris', 'France'),
#  ('National Archives, John F. Kennedy Presidential Library and Museum',
#   'United States'),
#  ('Muzeum Narodowe w Szczecinie', 'Poland'),
#  ('VMFA, Virginia Museum of Fine Arts', 'United States'),
#  ('Barber Institute of Fine Arts', 'United Kingdom'),
#  ('Museu Nacional de Etnologia', 'Portugal'),
#  ('Musée national Picasso Paris', 'France'),
#  ('National Gallery of Art', 'United States'),
#  ('Museum Folkwang', 'Germany'),
#  ('Michael C. Carlos Museum, Emory University', 'United States'),
#  ('Fleming Museum of Art, University of Vermont', 'United States'),
#  ("Musée d'Ethnographie de Neuchâtel", 'Switzerland'),
#  ('Gustavianum - Uppsala University Museum', 'Sweden'),
#  ('Hunt Museum', 'Ireland'),
#  ('Museum of Anthropology at UBC', 'Canada'),
#  ('Institut für Ethnologie und Afrikastudien, Johannes Gutenberg-Universität Mainz',
#   'Germany'),
#  ('Canadian Museum of History / Musée canadien de l’histoire', 'Canada'),
#  ('Landesmuseum Hannover, Das WeltenMuseum', 'Germany'),
#  ('Institut für Ethnologie und Ethnologische Sammlung der Universität Göttingen',
#   'Germany'),
#  ('RISD Museum, Museum of Art at Rhode Island School of Design',
#   'United States'),
#  ('Carnegie Museum of Art', 'United States'),
#  ('Allen Memorial Art Museum, Oberlin College', 'United States'),
#  ('Newark Museum of Art', 'United States'),
#  ('LACMA The Los Angeles County Museum of Art', 'United States'),
#  ('Hood Museum of Art', 'United States'),
#  ('Phoebe A. Hearst Museum of Anthropology, University of California at Berkeley',
#   'United States')]

# %%
df = pd.DataFrame(museum_list)
df.columns = ["Museum_name", "Country"]
df
# Out:
#                                            Museum_name         Country
# 0                                       British Museum  United Kingdom
# 1    Ethnologisches Museum, Staatliche Museen zu Be...         Germany
# 2                                         Field Museum   United States
# 3    Museum of Archaeology and Anthropology, Univer...  United Kingdom
# 4                               National Museum, Benin         Nigeria
# ..                                                 ...             ...
# 126         Allen Memorial Art Museum, Oberlin College   United States
# 127                               Newark Museum of Art   United States
# 128         LACMA The Los Angeles County Museum of Art   United States
# 129                                 Hood Museum of Art   United States
# 130  Phoebe A. Hearst Museum of Anthropology, Unive...   United States
#
# [131 rows x 2 columns]

# %%
df.to_csv("disputed-benin-artwork.csv", encoding = "UTF-8", index = "False")
